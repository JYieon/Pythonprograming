# %% [markdown]
# # Ch13. 파리바게뜨와 감탄떡볶이의 거리 구하기

# %% [markdown]
# ## 1. 프로젝트 소개 및 공공데이터 가져오기

# %% [markdown]
# **이디야의 입점 전략은 스타벅스 옆일까?**
#
# <img src=https://i.ibb.co/WcPXwdY/image.jpg, width=600>
#
# 논문) 위치 정보를 활용한 커피 전문점의 입점 분석 :
# https://koreascience.kr/article/JAKO201625058596417.pdf

# %% [markdown]
# **감탄 떡볶이의 입점전략은 파리바게트옆인가?**
#
# <img src=https://i.ibb.co/k9b4R6j/IMG-2017.jpg, width=600>
#
#
# 감탄떡볶이 (구 아딸떡볶이)의 이경수 대표의 인터뷰
#
# ◆"파리바게뜨 옆에 떡볶이집을 차려라"
#
# ―점포 위치 선정하는 원칙이 독특하던데요.
#
# **"저는 창업주들께 '아파트 입구, 횡단보도 앞, 파리바게뜨 옆'을 추천합니다."**
#
# ―'파리바게뜨 옆'은 뭡니까.
#
# "파리바게뜨는 전액 포장매출입니다. '아딸'의 목표와 같습니다. 그리고 사는 사람은 어른이지만 누구나 좋아하는 음식이란 공통점도 있습니다."
#
# ―파리바게뜨는 되고 뚜레쥬르는 안됩니까.
#
# "(웃으며) 됩니다. 그런데 파리바게뜨 숫자가 훨씬 많습니다. 장사 잘되는 저희 점포를 보면 대개 파리바게뜨 옆입니다. 횡단보도는 동네와 동네를 잇는 다리입니다. 그곳에 사람들이 모이죠. 신호를 기다리면서 건너편 가게들을 보게 되는 이점도 있습니다."
#
# 인터뷰 링크 : https://www.chosun.com/site/data/html_dir/2011/09/02/2011090201323.html
#
# 이번 단원에서 감탄떡볶이의 입점이 파리바게트 옆인지 알아보기 위해 거리를 구해보자

# %% [markdown]
# **공공데이터**
#
# 소상공인시장진흥공단_상가(상권)정보 : https://www.data.go.kr/data/15083033/fileData.do
#
#
# 링크에서 csv파일을 다운받고 서울의 데이터를 이용해서 실습을 해도 된다
#
# ```python
# # 예시 코드
# import pandas as pd
# url1 = './소상공인시장진흥공단_상가(상권)정보_서울_202212.csv'
# pd.read_csv(url1, engine='python', encoding='utf-8')
# ```

# %% [markdown]
# **실습에 쓰일 데이터**
#
# 다운받아 실습하는 것이 불편할 수강생을 위해 다운받은 공공데이터의 일부 열만 추린 csv파일을 사용한다.

# %% [markdown]
# 과연 감탄떡볶이의 입점전략이 파리바게트 옆인지 알아보기위해 감탄떡볶이외 국대떡볶이, 죠스떡볶이, 엽기떡볶이, 신전떡볶이와 파리바게트의 거리를 구해서 비교해보자

# %%
# 프로젝트 코드
import pandas as pd
pd.options.display.max_rows = 6
pd.options.display.float_format = '{:.4f}'.format
url = './13_01_food_business_seoul_20221231.csv'
tt = ['감탄떡볶이', '국대떡볶이', '죠스떡볶이', '엽기떡볶이', '신전떡볶이']

# %%
df = pd.read_csv(url)
df
# Out:
#          상가업소번호      상호명    지점명 상권업종중분류명   상권업종소분류명 시군구명  행정동명  \
# 0      17174175      비지트    NaN       한식  한식/백반/한정식  서초구  방배4동
# 1      17174119     쓰리에프    NaN       한식  한식/백반/한정식  동작구  사당2동
# 2      17174040       다향    NaN       한식  한식/백반/한정식  서초구  서초3동
# ...         ...      ...    ...      ...        ...  ...   ...
# 90829  17264432   북창동순두부  서초반포점       한식  한식/백반/한정식  서초구  반포1동
# 90830  17258497    혼밥순대국    NaN       한식  한식/백반/한정식  서초구  반포1동
# 90831  17266145  부산아지매국밥  신논현역점       한식  한식/백반/한정식  강남구  논현1동
#
#                        도로명주소       경도      위도
# 0        서울특별시 서초구 동광로18길 82 126.9914 37.4884
# 1      서울특별시 동작구 동작대로27가길 12 126.9810 37.4871
# 2          서울특별시 서초구 효령로 230 127.0094 37.4834
# ...                      ...      ...     ...
# 90829       서울특별시 서초구 주흥길 10 127.0208 37.5043
# 90830     서울특별시 서초구 강남대로 523 127.0220 37.5087
# 90831  서울특별시 강남구 강남대로112길 30 127.0268 37.5057
#
# [90832 rows x 10 columns]

# %% [markdown]
# ## 2. 떡볶이 프랜차이즈와 파리바게뜨의 데이터 추출하기

# %%
# 프로젝트 코드
import pandas as pd
pd.options.display.max_rows = 6
pd.options.display.float_format = '{:.4f}'.format
url = './13_01_food_business_seoul_20221231.csv'
tt = ['감탄떡볶이', '국대떡볶이', '죠스떡볶이', '엽기떡볶이', '신전떡볶이']
df = pd.read_csv(url)

# %% [markdown]
# 먼저 파리바게뜨의 데이터 추출하기
#
# `str.contains`는 특정 문자열 포함여부를 True, False로 반환하는 함수

# %%
# 파리바게뜨 데이터 필터링하고 정제하기
cond1 = df['상호명'].str.contains(r'파리바게뜨|파리바게트')
df_paris = df.loc[cond1, ['상가업소번호', '경도', '위도']].copy()
df_paris = (df_paris
            .set_axis(['p_업소번호', 'p_경도', 'p_위도'], axis=1)
            .reset_index(drop=True))
df_paris
# Out:
#        p_업소번호     p_경도    p_위도
# 0    26669769 126.8839 37.4903
# 1     9171904 127.0330 37.6078
# 2    23396020 126.9886 37.5742
# ..        ...      ...     ...
# 356  20589842 126.9019 37.4522
# 357  20595157 127.1310 37.5101
# 358  17182192 127.1644 37.5569
#
# [359 rows x 3 columns]

# %% [markdown]
# 떡볶이 프랜차이즈의 데이터 추출하기
#
# 이번에는 떡볶이 프랜차이즈의 상호를 추출하기 위해
# `str.contains` 대신 `str.extract`함수를 쓴다
#
# `str.extract`함수는 특정 문자열을 포함하고 있다면 그 문자열을 반환하고 아니면 NaN을  반환하는 함수

# %%
# 떡볶이 프랜차이즈 데이터 필터링하고 정제하기
df_tt = df.copy()
df_tt['상호명'] = df_tt['상호명'].str.extract(r'({})'.format('|'.join(tt)))[0]
df_tt = (df_tt
         .dropna(subset=['상호명'])
         .iloc[:, [0, 1, 5, 8, 9]]
         .reset_index(drop=True))
df_tt
# Out:
#        상가업소번호    상호명  시군구명       경도      위도
# 0    20844443  신전떡볶이   중랑구 127.1014 37.6003
# 1    25541815  신전떡볶이   중랑구 127.0794 37.6119
# 2    20738752  엽기떡볶이   양천구 126.8535 37.5210
# ..        ...    ...   ...      ...     ...
# 257  23444901  죠스떡볶이  영등포구 126.9058 37.5140
# 258  16990013  신전떡볶이   용산구 126.9992 37.5278
# 259  20081411  국대떡볶이   서초구 126.9966 37.4814
#
# [260 rows x 5 columns]

# %% [markdown]
# ## 3. 곱집합(cartesian product) & 위도와 경도로 거리구하기(haversine)

# %%
# 프로젝트 코드
import pandas as pd
pd.options.display.max_rows = 6
pd.options.display.float_format = '{:.4f}'.format
url = './13_01_food_business_seoul_20221231.csv'
tt = ['감탄떡볶이', '국대떡볶이', '죠스떡볶이', '엽기떡볶이', '신전떡볶이']
df = pd.read_csv(url)

# 파리바게뜨 데이터 필터링하고 정제하기
cond1 = df['상호명'].str.contains(r'파리바게뜨|파리바게트')
df_paris = df.loc[cond1, ['상가업소번호', '경도', '위도']].copy()
df_paris = (df_paris
            .set_axis(['p_업소번호', 'p_경도', 'p_위도'], axis=1)
            .reset_index(drop=True))

# 떡볶이 프랜차이즈 데이터 필터링하고 정제하기
df_tt = df.copy()
df_tt['상호명'] = df_tt['상호명'].str.extract(r'({})'.format('|'.join(tt)))[0]
df_tt = (df_tt
         .dropna(subset=['상호명'])
         .iloc[:, [0, 1, 5, 8, 9]]
         .reset_index(drop=True))

# %% [markdown]
# **특정 떡볶이 가게와 파리바게트와의 거리는 어떻게 구해야 할까?**
#
# <img src=https://i.ibb.co/5W32nx5/13-03-01.png, width=600>
#
# 특정 가게와 모든 파리바게뜨와의 거리를 구한 뒤 최소값이 그 가게에서 파리바게뜨와의 거리이다

# %% [markdown]
# **곱집합이란?**
#
# 양측의 모든 순서쌍을 만드는 조합
#
# 과거 경우의 수에서도 쓰였다
#
# <img src=https://i.ibb.co/8PJczYn/13-03.png, width=600>
#
# 각 떡볶이 상가와 모든 파리바게뜨의 거리를 구하기 위해 곱집합을 만들겠다

# %%
# 곱집합(cartesian product)을 만드는 cross join
df1 = pd.DataFrame(['A', 'B'])
df2 = pd.DataFrame(['가', '나', '다'])
df1.merge(df2, how='cross')
# Out:
#   0_x 0_y
# 0   A   가
# 1   A   나
# 2   A   다
# 3   B   가
# 4   B   나
# 5   B   다

# %%
# df_tt와 df_paris의 곱집합 만들기
df_cross = df_tt.merge(df_paris, how='cross')
df_cross
# Out:
#          상가업소번호    상호명 시군구명       경도      위도    p_업소번호     p_경도    p_위도
# 0      20844443  신전떡볶이  중랑구 127.1014 37.6003  26669769 126.8839 37.4903
# 1      20844443  신전떡볶이  중랑구 127.1014 37.6003   9171904 127.0330 37.6078
# 2      20844443  신전떡볶이  중랑구 127.1014 37.6003  23396020 126.9886 37.5742
# ...         ...    ...  ...      ...     ...       ...      ...     ...
# 93337  20081411  국대떡볶이  서초구 126.9966 37.4814  20589842 126.9019 37.4522
# 93338  20081411  국대떡볶이  서초구 126.9966 37.4814  20595157 127.1310 37.5101
# 93339  20081411  국대떡볶이  서초구 126.9966 37.4814  17182192 127.1644 37.5569
#
# [93340 rows x 8 columns]

# %% [markdown]
# ** 두 가게 사이의 거리구하기 **
#
# 두 지점의 위도와 경도를 입력하면 거리를 구해주는 라이브러리 `haversine` 을 이용한다

# %%
# haversine 라이브러리 설치하기
import sys
# !{sys.executable} -m pip install haversine
# Out:
# Requirement already satisfied: haversine in c:\users\6206-14\appdata\local\programs\python\python38\lib\site-packages (2.8.1)

# %%
# haversine 사용법

from haversine import haversine
#  서울과 파리의 위도와 경도(위도 경도순)
seoul = [37.541, 126.986]
paris = [48.8567, 2.3508]

# 서울과 파리사이의 거리 계산
haversine(seoul, paris, unit='m') # 변수로 넣을 경우
haversine([37.541, 126.986], [48.8567, 2.3508], unit='m') # 리스트로
# Out:
# 8968562.580161477

# %% [markdown]
# 단 `haversine` 함수를 하나의 행의 여러열로 적용하려면 데이터프레임에 바로 적용되는 함수가 아니므로 `apply`의 도움이 필요하다

# %%
# df_cross에 거리열 만들기
from haversine import haversine
df_cross['거리'] = df_cross.apply(
    lambda x: haversine([x[4],x[3]], [x[7], x[6]], unit='m'), 
    axis=1)
df_cross
# Out:
#          상가업소번호    상호명 시군구명       경도      위도    p_업소번호     p_경도    p_위도  \
# 0      20844443  신전떡볶이  중랑구 127.1014 37.6003  26669769 126.8839 37.4903
# 1      20844443  신전떡볶이  중랑구 127.1014 37.6003   9171904 127.0330 37.6078
# 2      20844443  신전떡볶이  중랑구 127.1014 37.6003  23396020 126.9886 37.5742
# ...         ...    ...  ...      ...     ...       ...      ...     ...
# 93337  20081411  국대떡볶이  서초구 126.9966 37.4814  20589842 126.9019 37.4522
# 93338  20081411  국대떡볶이  서초구 126.9966 37.4814  20595157 127.1310 37.5101
# 93339  20081411  국대떡볶이  서초구 126.9966 37.4814  17182192 127.1644 37.5569
#
#               거리
# 0     22745.8986
# 1      6080.4618
# 2     10356.9671
# ...          ...
# 93337  8969.1388
# 93338 12272.9853
# 93339 17013.7789
#
# [93340 rows x 9 columns]

# %% [markdown]
# ## 4. 떡볶이 프랜차이즈와 파리바게뜨의 거리 다양하게 집계하기

# %%
# 프로젝트 코드1 (도합 3개의 코드를 모두 copy해서 실행해야 한다)
import pandas as pd
pd.options.display.max_rows = 6
pd.options.display.float_format = '{:.4f}'.format
url = './13_01_food_business_seoul_20221231.csv'
tt = ['감탄떡볶이', '국대떡볶이', '죠스떡볶이', '엽기떡볶이', '신전떡볶이']
df = pd.read_csv(url)

# 파리바게뜨 데이터 필터링하고 정제하기
cond1 = df['상호명'].str.contains(r'파리바게뜨|파리바게트')
df_paris = df.loc[cond1, ['상가업소번호', '경도', '위도']].copy()
df_paris = (df_paris
            .set_axis(['p_업소번호', 'p_경도', 'p_위도'], axis=1)
            .reset_index(drop=True))

# 떡볶이 프랜차이즈 데이터 필터링하고 정제하기
df_tt = df.copy()
df_tt['상호명'] = df_tt['상호명'].str.extract(r'({})'.format('|'.join(tt)))[0]
df_tt = (df_tt
         .dropna(subset=['상호명'])
         .iloc[:, [0, 1, 5, 8, 9]]
         .reset_index(drop=True))

# df_tt와 df_paris의 곱집합 만들기
df_cross = df_tt.merge(df_paris, how='cross')

# %%
# 프로젝트 코드2
import sys
# !{sys.executable} -m pip install haversine
# Out:
# Requirement already satisfied: haversine in c:\users\6206-14\appdata\local\programs\python\python38\lib\site-packages (2.8.1)

# %%
# 프로젝트 코드3
from haversine import haversine
df_cross['거리'] = df_cross.apply(
    lambda x: haversine([x[4],x[3]], [x[7], x[6]], unit='m'), 
    axis=1)

# %%
# 개별 떡볶이 매장과 파리바게뜨와의 거리
df_dis = df_cross.groupby(['상가업소번호', '상호명'])['거리'].min().reset_index()
df_dis
# Out:
#        상가업소번호    상호명       거리
# 0     8616690  신전떡볶이 392.8313
# 1     8625310  신전떡볶이 606.1897
# 2    10520263  죠스떡볶이 327.7421
# ..        ...    ...      ...
# 257  28513476  엽기떡볶이 446.9590
# 258  28514842  엽기떡볶이 753.3187
# 259  28519528  신전떡볶이 725.6968
#
# [260 rows x 3 columns]

# %%
# 프랜차이즈 별 파리바게뜨와의 평균 거리
df_dis.groupby('상호명')['거리'].mean()
# Out:
# 상호명
# 감탄떡볶이   474.1331
# 국대떡볶이   377.8993
# 신전떡볶이   420.6615
# 엽기떡볶이   476.6015
# 죠스떡볶이   467.2652
# Name: 거리, dtype: float64

# %%
# 프랜차이즈 별 파리바게뜨와의 평균 거리와 매장개수
df_dis.groupby('상호명')['거리'].agg(['mean', 'count'])
# Out:
#           mean  count
# 상호명
# 감탄떡볶이 474.1331     55
# 국대떡볶이 377.8993     14
# 신전떡볶이 420.6615     58
# 엽기떡볶이 476.6015     92
# 죠스떡볶이 467.2652     41

# %%
# 프랜차이즈 별 파리바게뜨와 50m미만인 매장의 평균거리와 매장개수
cond = df_dis['거리'] < 50
df_dis[cond].groupby('상호명')['거리'].agg(['mean', 'count'])
# Out:
#          mean  count
# 상호명
# 감탄떡볶이 15.2256      7
# 국대떡볶이 19.3064      2
# 신전떡볶이 49.3257      1
# 엽기떡볶이 27.7970      5
# 죠스떡볶이 13.6234      5

# %%
# 프랜차이즈 별 파리바게뜨와 30m미만인 매장의 평균거리와 매장개수
cond = df_dis['거리'] < 30
df_dis[cond].groupby('상호명')['거리'].agg(['mean', 'count'])
# Out:
#          mean  count
# 상호명
# 감탄떡볶이  0.0000      4
# 국대떡볶이  0.0000      1
# 엽기떡볶이 17.9833      3
# 죠스떡볶이  4.7981      4

# %%
# 거리에 따라 집계를 해주는 함수를 만들자
def distance(x):
  cond = df_dis['거리'] < x
  return df_dis[cond].groupby('상호명')['거리'].agg(['mean', 'count'])
distance(100)
# Out:
#          mean  count
# 상호명
# 감탄떡볶이 33.6436     10
# 국대떡볶이 41.0192      3
# 신전떡볶이 80.7178      5
# 엽기떡볶이 59.2283     11
# 죠스떡볶이 51.1618     11

# %% [markdown]
# ## 5. 감탄떡볶이의 입점전략 시각화하기

# %% [markdown]
# **pyecharts**
#
# echarts를 python에서 사용할 수 있게 해주는 라이브러리
#
# - 기본값이 예쁘다
# - 반응형이다
#
# pyecharts 사이트 링크 : https://pyecharts.org/#/en-us/
#
# 갤러리 링크 : https://gallery.pyecharts.org/#/README_EN
#
# pyecharts 설치 (1.9.1버전 설치)
#
# ```python
# import sys
# !{sys.executable} -m pip install --upgrade pyecharts==1.9.1
# ```
#
# **pandasecharts**
#
# 데이터 프레임에 pyecharts를 쉽게 사용하게 해주는 라이브러리
#
#
#
#
# pandasecharts 설치
#
# ```python
# import sys
# !{sys.executable} -m pip install pandasecharts
# ```

# %%
# pyecharts 1.9.1 설치
import sys
# !{sys.executable} -m pip install --upgrade pyecharts==1.9.1
# Out:
# Requirement already satisfied: pyecharts==1.9.1 in c:\users\6206-14\appdata\local\programs\python\python38\lib\site-packages (1.9.1)
# Requirement already satisfied: jinja2 in c:\users\6206-14\appdata\local\programs\python\python38\lib\site-packages (from pyecharts==1.9.1) (3.1.4)
# Requirement already satisfied: prettytable in c:\users\6206-14\appdata\local\programs\python\python38\lib\site-packages (from pyecharts==1.9.1) (3.10.0)
# Requirement already satisfied: simplejson in c:\users\6206-14\appdata\local\programs\python\python38\lib\site-packages (from pyecharts==1.9.1) (3.19.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\6206-14\appdata\local\programs\python\python38\lib\site-packages (from jinja2->pyecharts==1.9.1) (2.1.5)
# Requirement already satisfied: wcwidth in c:\users\6206-14\appdata\roaming\python\python38\site-packages (from prettytable->pyecharts==1.9.1) (0.2.13)

# %%
# pandasecharts 설치
import sys
# !{sys.executable} -m pip install pandasecharts
# Out:
# Collecting pandasecharts
#   Downloading pandasecharts-0.5-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: pandas in c:\users\6206-14\appdata\local\programs\python\python38\lib\site-packages (from pandasecharts) (2.0.3)
# Requirement already satisfied: pyecharts>=1.0.0 in c:\users\6206-14\appdata\local\programs\python\python38\lib\site-packages (from pandasecharts) (1.9.1)
# Requirement already satisfied: jinja2 in c:\users\6206-14\appdata\local\programs\python\python38\lib\site-packages (from pyecharts>=1.0.0->pandasecharts) (3.1.4)
# Requirement already satisfied: prettytable in c:\users\6206-14\appdata\local\programs\python\python38\lib\site-packages (from pyecharts>=1.0.0->pandasecharts) (3.10.0)
# Requirement already satisfied: simplejson in c:\users\6206-14\appdata\local\programs\python\python38\lib\site-packages (from pyecharts>=1.0.0->pandasecharts) (3.19.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\6206-14\appdata\roaming\python\python38\site-packages (from pandas->pandasecharts) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\6206-14\appdata\local\programs\python\python38\lib\site-packages (from pandas->pandasecharts) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\6206-14\appdata\local\programs\python\python38\lib\site-packages (from pandas->pandasecharts) (2024.1)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\6206-14\appdata\local\programs\python\python38\lib\site-packages (from pandas->pandasecharts) (1.24.4)
# Requirement already satisfied: six>=1.5 in c:\users\6206-14\appdata\local\programs\python\python38\lib\site-packages (from python-dateutil>=2.8.2->pandas->pandasecharts) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\6206-14\appdata\local\programs\python\python38\lib\site-packages (from jinja2->pyecharts>=1.0.0->pandasecharts) (2.1.5)
# Requirement already satisfied: wcwidth in c:\users\6206-14\appdata\roaming\python\python38\site-packages (from prettytable->pyecharts>=1.0.0->pandasecharts) (0.2.13)
# Downloading pandasecharts-0.5-py3-none-any.whl (15 kB)
# Installing collected packages: pandasecharts
# Successfully installed pandasecharts-0.5

# %%
# haversine 설치
import sys
# !{sys.executable} -m pip install haversine
# Out:
# Requirement already satisfied: haversine in c:\users\6206-14\appdata\local\programs\python\python38\lib\site-packages (2.8.1)

# %%
# 프로젝트 코드
import pandas as pd
from haversine import haversine
from pyecharts.charts import Timeline, Grid
from pandasecharts import echart
import IPython

pd.options.display.max_rows = 6
pd.options.display.float_format = '{:.4f}'.format
url = './13_01_food_business_seoul_20221231.csv'
tt = ['감탄떡볶이', '국대떡볶이', '죠스떡볶이', '엽기떡볶이', '신전떡볶이']
df = pd.read_csv(url)

# 파리바게뜨 데이터 필터링하고 정제하기
cond1 = df['상호명'].str.contains(r'파리바게뜨|파리바게트')
df_paris = df.loc[cond1, ['상가업소번호', '경도', '위도']].copy()
df_paris = (df_paris
            .set_axis(['p_업소번호', 'p_경도', 'p_위도'], axis=1)
            .reset_index(drop=True))

# 떡볶이 프랜차이즈 데이터 필터링하고 정제하기
df_tt = df.copy()
df_tt['상호명'] = df_tt['상호명'].str.extract(r'({})'.format('|'.join(tt)))[0]
df_tt = (df_tt
         .dropna(subset=['상호명'])
         .iloc[:, [0, 1, 5, 8, 9]]
         .reset_index(drop=True))

# df_tt와 df_paris의 곱집합 만들기
df_cross = df_tt.merge(df_paris, how='cross')

# df_cross에 거리열 만들기
df_cross['거리'] = df_cross.apply(
    lambda x: haversine([x[4],x[3]], [x[7], x[6]], unit='m'), 
    axis=1)

# 개별 떡볶이 매장과 파리바게뜨와의 거리
df_dis = df_cross.groupby(['상가업소번호', '상호명'])['거리'].min().reset_index()


# 거리에 따라 프랜차이즈별 평균 거리와 매장수를 집계를 해주는 함수
def distance(x):
  cond = df_dis['거리'] < x
  return df_dis[cond].groupby('상호명')['거리'].agg(['mean', 'count'])

# %% [markdown]
# pyecharts로 만든 그래프를 구글 코랩에 출력하는 코드
#
# ```python
# IPython.display.HTML(filename='/content/render.html')
# ```

# %% [markdown]
# 거리마다 데이터를 집계해주는 사용자 정의 함수 `distance`를 활용한다

# %%
# distance 함수로 50m의 집계하기(reset_index로 상호명도 열로 만든다)
distance(50).reset_index()
# Out:
#      상호명    mean  count
# 0  감탄떡볶이 15.2256      7
# 1  국대떡볶이 19.3064      2
# 2  신전떡볶이 49.3257      1
# 3  엽기떡볶이 27.7970      5
# 4  죠스떡볶이 13.6234      5

# %%
# 50m의 데이터로 원형 그래프 만들기
df_g = distance(50).reset_index()
df_g.echart.pie(x='상호명', y='count', figsize=(600, 400), 
                radius=['20%', '60%'], label_opts={'position':'outer'}, 
                title='감탄떡볶이의 입점전략은 과연 파리바게뜨 옆인가?', 
                legend_opts={'pos_right':'0%', 'orient':'vertical'}, 
                subtitle='50m 이내 매장수').render()
IPython.display.HTML(filename='./render.html')
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#             <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
#
# </head>
# <body>
#     <div id="7c8c1b6c0e074f7fb6c89a9e2039cd64" class="chart-container" style="width:600px; height:400px;"></div>
#     <script>
#         var chart_7c8c1b6c0e074f7fb6c89a9e2039cd64 = echarts.init(
#             document.getElementById('7c8c1b6c0e074f7fb6c89a9e2039cd64'), 'white', {renderer: 'canvas'});
#         var option_7c8c1b6c0e074f7fb6c89a9e2039cd64 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "name": "count",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\uac10\ud0c4\ub5a1\ubcf6\uc774",
#                     "value": 7
#                 },
#                 {
#                     "name": "\uad6d\ub300\ub5a1\ubcf6\uc774",
#                     "value": 2
#                 },
#                 {
#                     "name": "\uc2e0\uc804\ub5a1\ubcf6\uc774",
#                     "value": 1
#                 },
#                 {
#                     "name": "\uc5fd\uae30\ub5a1\ubcf6\uc774",
#                     "value": 5
#                 },
#                 {
#                     "name": "\uc8e0\uc2a4\ub5a1\ubcf6\uc774",
#                     "value": 5
#                 }
#             ],
#             "radius": [
#                 "20%",
#                 "60%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "outer",
#                 "margin": 8,
#                 "formatter": "{b}:{d}%"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\uac10\ud0c4\ub5a1\ubcf6\uc774",
#                 "\uad6d\ub300\ub5a1\ubcf6\uc774",
#                 "\uc2e0\uc804\ub5a1\ubcf6\uc774",
#                 "\uc5fd\uae30\ub5a1\ubcf6\uc774",
#                 "\uc8e0\uc2a4\ub5a1\ubcf6\uc774"
#             ],
#             "selected": {},
#             "show": true,
#             "right": "0%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\uac10\ud0c4\ub5a1\ubcf6\uc774\uc758 \uc785\uc810\uc804\ub7b5\uc740 \uacfc\uc5f0 \ud30c\ub9ac\ubc14\uac8c\ub728 \uc606\uc778\uac00?",
#             "subtext": "50m \uc774\ub0b4 \ub9e4\uc7a5\uc218",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_7c8c1b6c0e074f7fb6c89a9e2039cd64.setOption(option_7c8c1b6c0e074f7fb6c89a9e2039cd64);
#     </script>
# </body>
# </html>

# %%
# 앞서 만든 그래프를 timeline으로 만들기
tl = Timeline({'width':'600px', 'height': '400px'})
df_g = distance(50).reset_index()
pie1 = df_g.echart.pie(x='상호명', y='count', figsize=(600, 400), 
                       radius=['20%', '60%'], label_opts={'position':'outer'}, 
                       title='감탄떡볶이의 입점전략은 과연 파리바게뜨 옆인가?', 
                       legend_opts={'pos_right':'0%', 'orient':'vertical'}, 
                       subtitle='50m 이내 매장수')
tl.add(pie1, '50m').render()
IPython.display.HTML(filename='./render.html')
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#             <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
#
# </head>
# <body>
#     <div id="d7fc006c73574190aa67b94738d8b25e" class="chart-container" style="width:600px; height:400px;"></div>
#     <script>
#         var chart_d7fc006c73574190aa67b94738d8b25e = echarts.init(
#             document.getElementById('d7fc006c73574190aa67b94738d8b25e'), 'white', {renderer: 'canvas'});
#         var option_d7fc006c73574190aa67b94738d8b25e = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "pie",
#                 "name": "count",
#                 "clockwise": true,
#                 "data": [
#                     {
#                         "name": "\uac10\ud0c4\ub5a1\ubcf6\uc774",
#                         "value": 7
#                     },
#                     {
#                         "name": "\uad6d\ub300\ub5a1\ubcf6\uc774",
#                         "value": 2
#                     },
#                     {
#                         "name": "\uc2e0\uc804\ub5a1\ubcf6\uc774",
#                         "value": 1
#                     },
#                     {
#                         "name": "\uc5fd\uae30\ub5a1\ubcf6\uc774",
#                         "value": 5
#                     },
#                     {
#                         "name": "\uc8e0\uc2a4\ub5a1\ubcf6\uc774",
#                         "value": 5
#                     }
#                 ],
#                 "radius": [
#                     "20%",
#                     "60%"
#                 ],
#                 "center": [
#                     "50%",
#                     "50%"
#                 ],
#                 "label": {
#                     "show": true,
#                     "position": "outer",
#                     "margin": 8,
#                     "formatter": "{b}:{d}%"
#                 },
#                 "rippleEffect": {
#                     "show": true,
#                     "brushType": "stroke",
#                     "scale": 2.5,
#                     "period": 4
#                 }
#             }
#         ],
#         "timeline": {
#             "axisType": "category",
#             "orient": "horizontal",
#             "autoPlay": false,
#             "controlPosition": "left",
#             "loop": true,
#             "rewind": false,
#             "show": true,
#             "inverse": false,
#             "bottom": "-5px",
#             "data": [
#                 "50m"
#             ]
#         }
#     },
#     "options": [
#         {
#             "legend": [
#                 {
#                     "data": [
#                         "\uac10\ud0c4\ub5a1\ubcf6\uc774",
#                         "\uad6d\ub300\ub5a1\ubcf6\uc774",
#                         "\uc2e0\uc804\ub5a1\ubcf6\uc774",
#                         "\uc5fd\uae30\ub5a1\ubcf6\uc774",
#                         "\uc8e0\uc2a4\ub5a1\ubcf6\uc774"
#                     ],
#                     "selected": {},
#                     "show": true,
#                     "right": "0%",
#                     "orient": "vertical",
#                     "padding": 5,
#                     "itemGap": 10,
#                     "itemWidth": 25,
#                     "itemHeight": 14
#                 }
#             ],
#             "series": [
#                 {
#                     "type": "pie",
#                     "name": "count",
#                     "clockwise": true,
#                     "data": [
#                         {
#                             "name": "\uac10\ud0c4\ub5a1\ubcf6\uc774",
#                             "value": 7
#                         },
#                         {
#                             "name": "\uad6d\ub300\ub5a1\ubcf6\uc774",
#                             "value": 2
#                         },
#                         {
#                             "name": "\uc2e0\uc804\ub5a1\ubcf6\uc774",
#                             "value": 1
#                         },
#                         {
#                             "name": "\uc5fd\uae30\ub5a1\ubcf6\uc774",
#                             "value": 5
#                         },
#                         {
#                             "name": "\uc8e0\uc2a4\ub5a1\ubcf6\uc774",
#                             "value": 5
#                         }
#                     ],
#                     "radius": [
#                         "20%",
#                         "60%"
#                     ],
#                     "center": [
#                         "50%",
#                         "50%"
#                     ],
#                     "label": {
#                         "show": true,
#                         "position": "outer",
#                         "margin": 8,
#                         "formatter": "{b}:{d}%"
#                     },
#                     "rippleEffect": {
#                         "show": true,
#                         "brushType": "stroke",
#                         "scale": 2.5,
#                         "period": 4
#                     }
#                 }
#             ],
#             "title": [
#                 {
#                     "text": "\uac10\ud0c4\ub5a1\ubcf6\uc774\uc758 \uc785\uc810\uc804\ub7b5\uc740 \uacfc\uc5f0 \ud30c\ub9ac\ubc14\uac8c\ub728 \uc606\uc778\uac00?",
#                     "subtext": "50m \uc774\ub0b4 \ub9e4\uc7a5\uc218",
#                     "padding": 5,
#                     "itemGap": 10
#                 }
#             ],
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "showContent": true,
#                 "alwaysShowContent": false,
#                 "showDelay": 0,
#                 "hideDelay": 100,
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0,
#                 "padding": 5
#             },
#             "color": [
#                 "#c23531",
#                 "#2f4554",
#                 "#61a0a8",
#                 "#d48265",
#                 "#749f83",
#                 "#ca8622",
#                 "#bda29a",
#                 "#6e7074",
#                 "#546570",
#                 "#c4ccd3",
#                 "#f05b72",
#                 "#ef5b9c",
#                 "#f47920",
#                 "#905a3d",
#                 "#fab27b",
#                 "#2a5caa",
#                 "#444693",
#                 "#726930",
#                 "#b2d235",
#                 "#6d8346",
#                 "#ac6767",
#                 "#1d953f",
#                 "#6950a1",
#                 "#918597"
#             ]
#         }
#     ]
# };
#         chart_d7fc006c73574190aa67b94738d8b25e.setOption(option_d7fc006c73574190aa67b94738d8b25e);
#     </script>
# </body>
# </html>

# %%
# 반복문으로 1000m, 100m, 50m, 30m를 타임라인으로 만들기
tl = Timeline({'width':'600px', 'height': '400px'})
for i in [1000, 100, 50, 30]:
  df_g = distance(i).reset_index()
  pie1 = df_g.echart.pie(x='상호명', 
                         y='count', 
                         figsize=(600, 400), 
                         radius=['20%', '60%'], 
                         label_opts={'position':'outer'}, 
                         title='감탄떡볶이의 입점전략은 과연 파리바게뜨 옆인가?', 
                         legend_opts={'pos_right':'0%', 'orient':'vertical'}, 
                         subtitle='{}m 이내 매장수'.format(i))
  tl.add(pie1, '{}m'.format(i)).render()
IPython.display.HTML(filename='./render.html')
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#             <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
#
# </head>
# <body>
#     <div id="cf551c9cabdf4349b16c0843792f34bd" class="chart-container" style="width:600px; height:400px;"></div>
#     <script>
#         var chart_cf551c9cabdf4349b16c0843792f34bd = echarts.init(
#             document.getElementById('cf551c9cabdf4349b16c0843792f34bd'), 'white', {renderer: 'canvas'});
#         var option_cf551c9cabdf4349b16c0843792f34bd = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "pie",
#                 "name": "count",
#                 "clockwise": true,
#                 "data": [
#                     {
#                         "name": "\uac10\ud0c4\ub5a1\ubcf6\uc774",
#                         "value": 4
#                     },
#                     {
#                         "name": "\uad6d\ub300\ub5a1\ubcf6\uc774",
#                         "value": 1
#                     },
#                     {
#                         "name": "\uc5fd\uae30\ub5a1\ubcf6\uc774",
#                         "value": 3
#                     },
#                     {
#                         "name": "\uc8e0\uc2a4\ub5a1\ubcf6\uc774",
#                         "value": 4
#                     }
#                 ],
#                 "radius": [
#                     "20%",
#                     "60%"
#                 ],
#                 "center": [
#                     "50%",
#                     "50%"
#                 ],
#                 "label": {
#                     "show": true,
#                     "position": "outer",
#                     "margin": 8,
#                     "formatter": "{b}:{d}%"
#                 },
#                 "rippleEffect": {
#                     "show": true,
#                     "brushType": "stroke",
#                     "scale": 2.5,
#                     "period": 4
#                 }
#             }
#         ],
#         "timeline": {
#             "axisType": "category",
#             "orient": "horizontal",
#             "autoPlay": false,
#             "controlPosition": "left",
#             "loop": true,
#             "rewind": false,
#             "show": true,
#             "inverse": false,
#             "bottom": "-5px",
#             "data": [
#                 "1000m",
#                 "100m",
#                 "50m",
#                 "30m"
#             ]
#         }
#     },
#     "options": [
#         {
#             "legend": [
#                 {
#                     "data": [
#                         "\uac10\ud0c4\ub5a1\ubcf6\uc774",
#                         "\uad6d\ub300\ub5a1\ubcf6\uc774",
#                         "\uc2e0\uc804\ub5a1\ubcf6\uc774",
#                         "\uc5fd\uae30\ub5a1\ubcf6\uc774",
#                         "\uc8e0\uc2a4\ub5a1\ubcf6\uc774"
#                     ],
#                     "selected": {},
#                     "show": true,
#                     "right": "0%",
#                     "orient": "vertical",
#                     "padding": 5,
#                     "itemGap": 10,
#                     "itemWidth": 25,
#                     "itemHeight": 14
#                 }
#             ],
#             "series": [
#                 {
#                     "type": "pie",
#                     "name": "count",
#                     "clockwise": true,
#                     "data": [
#                         {
#                             "name": "\uac10\ud0c4\ub5a1\ubcf6\uc774",
#                             "value": 49
#                         },
#                         {
#                             "name": "\uad6d\ub300\ub5a1\ubcf6\uc774",
#                             "value": 14
#                         },
#                         {
#                             "name": "\uc2e0\uc804\ub5a1\ubcf6\uc774",
#                             "value": 58
#                         },
#                         {
#                             "name": "\uc5fd\uae30\ub5a1\ubcf6\uc774",
#                             "value": 87
#                         },
#                         {
#                             "name": "\uc8e0\uc2a4\ub5a1\ubcf6\uc774",
#                             "value": 39
#                         }
#                     ],
#                     "radius": [
#                         "20%",
#                         "60%"
#                     ],
#                     "center": [
#                         "50%",
#                         "50%"
#                     ],
#                     "label": {
#                         "show": true,
#                         "position": "outer",
#                         "margin": 8,
#                         "formatter": "{b}:{d}%"
#                     },
#                     "rippleEffect": {
#                         "show": true,
#                         "brushType": "stroke",
#                         "scale": 2.5,
#                         "period": 4
#                     }
#                 }
#             ],
#             "title": [
#                 {
#                     "text": "\uac10\ud0c4\ub5a1\ubcf6\uc774\uc758 \uc785\uc810\uc804\ub7b5\uc740 \uacfc\uc5f0 \ud30c\ub9ac\ubc14\uac8c\ub728 \uc606\uc778\uac00?",
#                     "subtext": "1000m \uc774\ub0b4 \ub9e4\uc7a5\uc218",
#                     "padding": 5,
#                     "itemGap": 10
#                 }
#             ],
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "showContent": true,
#                 "alwaysShowContent": false,
#                 "showDelay": 0,
#                 "hideDelay": 100,
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0,
#                 "padding": 5
#             },
#             "color": [
#                 "#c23531",
#                 "#2f4554",
#                 "#61a0a8",
#                 "#d48265",
#                 "#749f83",
#                 "#ca8622",
#                 "#bda29a",
#                 "#6e7074",
#                 "#546570",
#                 "#c4ccd3",
#                 "#f05b72",
#                 "#ef5b9c",
#                 "#f47920",
#                 "#905a3d",
#                 "#fab27b",
#                 "#2a5caa",
#                 "#444693",
#                 "#726930",
#                 "#b2d235",
#                 "#6d8346",
#                 "#ac6767",
#                 "#1d953f",
#                 "#6950a1",
#                 "#918597"
#             ]
#         },
#         {
#             "legend": [
#                 {
#                     "data": [
#                         "\uac10\ud0c4\ub5a1\ubcf6\uc774",
#                         "\uad6d\ub300\ub5a1\ubcf6\uc774",
#                         "\uc2e0\uc804\ub5a1\ubcf6\uc774",
#                         "\uc5fd\uae30\ub5a1\ubcf6\uc774",
#                         "\uc8e0\uc2a4\ub5a1\ubcf6\uc774"
#                     ],
#                     "selected": {},
#                     "show": true,
#                     "right": "0%",
#                     "orient": "vertical",
#                     "padding": 5,
#                     "itemGap": 10,
#                     "itemWidth": 25,
#                     "itemHeight": 14
#                 }
#             ],
#             "series": [
#                 {
#                     "type": "pie",
#                     "name": "count",
#                     "clockwise": true,
#                     "data": [
#                         {
#                             "name": "\uac10\ud0c4\ub5a1\ubcf6\uc774",
#                             "value": 10
#                         },
#                         {
#                             "name": "\uad6d\ub300\ub5a1\ubcf6\uc774",
#                             "value": 3
#                         },
#                         {
#                             "name": "\uc2e0\uc804\ub5a1\ubcf6\uc774",
#                             "value": 5
#                         },
#                         {
#                             "name": "\uc5fd\uae30\ub5a1\ubcf6\uc774",
